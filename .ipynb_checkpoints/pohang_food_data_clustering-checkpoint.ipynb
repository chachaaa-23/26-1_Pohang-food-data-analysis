# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import platform
import matplotlib.font_manager as fm
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocesisng import StandardScaler

#한글 폰트 설정
system = platform.system()
# Linux / Colab → install Nanum if needed
if system == "Linux":
    import subprocess
    subprocess.run(["apt-get", "install", "-y", "-qq", "fonts-nanum"])

# refresh matplotlib font list
fm._load_fontmanager(try_read_cache=False)

# choose font by OS
if system == "Windows":
    font = "Malgun Gothic"
elif system == "Darwin":
    font = "AppleGothic"
else:
    font = "NanumGothic"

plt.rcParams["font.family"] = font
matplotlib.rcParams["axes.unicode_minus"] = False
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 9
#       7 from sklearn.cluster import KMeans
#       8 from sklearn.decomposition import PCA
# ----> 9 from sklearn.preprocesisng import StandardScaler
#      11 #한글 폰트 설정
#      12 system = platform.system()
#
# ModuleNotFoundError: No module named 'sklearn.preprocesisng'

# %%
#1. 데이터 로드 
df = pd.read_csv('./project_data/pohang_food_by_dong.csv', encoding= 'utf-8')

#분석에 사용할 업종별 비율 컬럼
features = ['한식_ratio', '분식/패스트푸드_ratio', '카페/디저트_ratio', '주점_ratio', '중식_ratio', '일식_ratio', '양식/외국식_ratio', '기타음식_ratio']

#모델에 입력할 데이터
X = df[features]

#행정동 데이터 전체명 (ex.포항시 북구 양덕동)
df['full_dong'] = df['sigungu'] + ' ' + df['dong']
labels = df['full_dong']

print("AI 학습데이터 shape: ", X.shape)
print(X.head())
# Out:
# AI 학습데이터 shape:  (29, 8)
#    한식_ratio  분식/패스트푸드_ratio  카페/디저트_ratio  주점_ratio  중식_ratio  일식_ratio  \
# 0    0.4934          0.1820        0.1096    0.1318    0.0404    0.0198
# 1    0.4205          0.2048        0.1645    0.1024    0.0393    0.0329
# 2    0.4852          0.1478        0.0887    0.2340    0.0209    0.0172
# 3    0.4662          0.2030        0.1591    0.0977    0.0338    0.0175
# 4    0.4540          0.1528        0.1075    0.2136    0.0354    0.0226
#
#    양식/외국식_ratio  기타음식_ratio
# 0        0.0198      0.0033
# 1        0.0320      0.0037
# 2        0.0037      0.0025
# 3        0.0163      0.0063
# 4        0.0099      0.0042

# %%
#데이터 정규화
scalar = StandardScaler()
X_scaled = scaler.fit_transform(X)

#k-means cluster 적용
k=3
kmeans = KMeans(n_clusters=k, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

#PCA 차원축소
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
print(X_pca)

df['PC1'] = X_pca[:, 0]
df['PC2'] = X_pca[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #데이터 정규화
# ----> 2 scalar = StandardScaler()
#       3 X_scaled = scaler.fit_transform(X)
#       5 #k-means cluster 적용
#
# NameError: name 'StandardScaler' is not defined
